# %% [markdown]
# <a href="https://colab.research.google.com/github/Zyuuu-G/Quantum_code/blob/main/Quantum_hw_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import*
#import matplotlib as plt

# %% [markdown]
# # Quantum hw 1
# ####Ziyu Gao
# #####01/23/2023

# %% [markdown]
# #####1. What is the wave-particle duality of quantum mechanics and how does it affect matter?
#
#
# ##### A quantum object has property of both wave and particle. When it's not meaured, disturbed, or the wave fuction is not affected to collapse, it shows its properties of being a wave (interference). When it's measured and the wave function collapses, it's observed as a particle.

# %% [markdown]
# ######2. Schrodinger’s equation (time independent)
# $\frac{d^2}{dx^2}\psi(x)=-\frac{2m}{\hbar^2}(E-V(x))\psi(x)$

# %%
# 3. Schroeder problem 1.7

n, x = symbols ('n x')
A = 1
a = 1 

psi = A*sin(n*pi*x/a)

p1 = plot(psi.subs(n,1/2), psi.subs(n,1), psi.subs(n,3/2), (x,0,2), legend=True, show=False)

p1[0].line_color='black'
p1[1].line_color='purple'
p1[2].line_color='orange'

p1[0].label='1st'
p1[1].label='2ed'
p1[2].label='3rd'

p1.title = ('eigenfunctions of infinite square well @ HSU')

p1.show()

# %%
# 4. Schroeder 1.5

print('All wavelengths are in meters!\n')

hc  = 1240e-9 # eV*m*C
h = 6.63e-34 # J*s

# a) microwave photon
E_mw = 10e-5 # eV
lamb_mw = hc/E_mw
print('a) microwave photon\n', lamb_mw, 'm\n')

# b) electron
PC_e = 5000*1.60217663e-19 *6.242e+18 # 5kV to eV
lamb_e = hc/PC_e
print('b) electron\n',lamb_e,'m\n')


# c) rubidium-87 atom
KE_87 = 10e-11 # eV
PC_87 = sqrt(2*87*KE_87)  # non-relativistic p=sqrt(2m*KE)? What's the correct mass?
lamb_87 = hc/PC_87
print('c) rubidium-87 atom\n', lamb_87, 'm the # looks off :(\n')

# d) proton
PC_p = 6.5e12
lamb_p = hc/PC_p
print('d) proton\n', lamb_p, 'm\n')

# e) gnat
m = 0.2e-3 # grams
v = 0.5 # m/s
PC_KE = 0.5*m*v*v
lamb_gnat = h/(PC_KE*3e8)
print('e) gnat\n', lamb_gnat, 'm\n')
# Out:
# All wavelengths are in meters!
#
# a) microwave photon
#  0.0124 m
#
# b) electron
#  2.4798049572745074e-10 m
#
# c) rubidium-87 atom
#  0.00940041574037840 m the # looks off :(
#
# d) proton
#  1.9076923076923077e-19 m
#
# e) gnat
#  8.84e-38 m

# %%
# b) electron
PC_e = 5000*1.60217663e-19 *6.242e+18 # 5kV to eV
lamb_e = hc/PC_e
print(lamb_e)

# %% [markdown]
# #####5. Schroeder 1.7
# For the probability density plotted in Figure 1.4, make a rough graphical
# estimate of the probability of  nding the particle between a and b.
#
# The probability is given by the area under the curve from 'a' to 'b'. It's eyeballed to 20% (or 0.2).
